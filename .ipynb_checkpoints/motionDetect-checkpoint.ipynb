# %%
import cv2  #Görüntü işleme için OpenCV
from ultralytics import YOLO  # Cisimleri algılama için Ultralytics'den YOLO

model = YOLO('yolov8n.pt')  # YOLO'nun v8-Nano Modeli

cap = cv2.VideoCapture('test.mp4')  # Videoyu aç

fgbg = cv2.createBackgroundSubtractorMOG2()  # Arka plan çıkarma işlemi (Daha rahat hareket algılamak için) 

#Tüm kareler üzerinde işlem yapabilmek için frameleri döngüye sokuyoruz
while True:
    ret, frame = cap.read() #Her seferinde bir sonraki kareyi almak için (Ret -> return (True ya da False), frame -> Kare)
    if not ret: #Başka kare yoksa yani video bittiyse döngüyü bitir
        break

    
    fgmask = fgbg.apply(frame) #Arka plan çıkarma ve kontür bulma işlemi için maskeleme uygulanır. (Beyaz hareketli, siyah hareketsiz)
    contours, _ = cv2.findContours(fgmask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) #Hareket maskesindeki beyaz bölgeleri konturlara çevirir.

    results = model(frame) #Yolo modelinin frame üzerinde tahmin yapması

#Tahminlerin kare içine alınarak belirtilmesi
    #Her obje için hareket kontrolü
    for result in results:
        for box in result.boxes.xyxy:
            x1, y1, x2, y2 = map(int, box)
            #Obje ile hareketli kontur çakışıyor mu?
            motion_detected = False
            for contour in contours:
                if cv2.contourArea(contour) < 500:
                    continue
                (mx, my, mw, mh) = cv2.boundingRect(contour)
                if (x1 < mx + mw and x2 > mx and y1 < my + mh and y2 > my):
                    motion_detected = True
                    break
            #Çizim ve etiketleme
            if motion_detected:
                color = (0, 0, 255)  # Kırmızı (hareketli)
                label = 'MOTION'
            else:
                color = (0, 255, 0)  # Yeşil (sabit)
                label = 'STATIC'

            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    cv2.imshow('YOLOv8 + Hareket Tahmini', frame) #Tahminlerle birlikte gerçek görüntüyü göster

    cv2.imshow('FGMask', fgmask) #Maskelenmiş kontürleri çizilmiş şekilde göster (beyaz = hareket, siyah = arka plan)

    #Arka plan temizlenmiş görüntü
    masked_frame = cv2.bitwise_and(frame, frame, mask=fgmask)
    cv2.imshow('Arka Plan Temizlenmis', masked_frame)

    #Q tusuna basarak döngüden çıkmak - görüntüyü kapatmak
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 8 cars, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 12.2ms
# Speed: 3.3ms preprocess, 12.2ms inference, 5.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 16.4ms
# Speed: 4.3ms preprocess, 16.4ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 13.7ms
# Speed: 4.1ms preprocess, 13.7ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 16.5ms
# Speed: 5.9ms preprocess, 16.5ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 18.5ms
# Speed: 3.1ms preprocess, 18.5ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 15.2ms
# Speed: 3.8ms preprocess, 15.2ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 16.3ms
# Speed: 3.4ms preprocess, 16.3ms inference, 5.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 11.7ms
# Speed: 2.6ms preprocess, 11.7ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 13.0ms
# Speed: 3.9ms preprocess, 13.0ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 truck, 17.9ms
# Speed: 2.1ms preprocess, 17.9ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 truck, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 1 truck, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 19.6ms
# Speed: 2.3ms preprocess, 19.6ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 1 bus, 13.7ms
# Speed: 3.9ms preprocess, 13.7ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 1 truck, 15.8ms
# Speed: 2.5ms preprocess, 15.8ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 1 truck, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 bus, 1 truck, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 13.2ms
# Speed: 2.2ms preprocess, 13.2ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 bus, 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 bus, 9.4ms
# Speed: 3.5ms preprocess, 9.4ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 bus, 9.6ms
# Speed: 3.1ms preprocess, 9.6ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 bus, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 6.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 1 truck, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 1 bus, 1 truck, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 1 truck, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 1 truck, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 1 bus, 1 truck, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 truck, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 truck, 10.7ms
# Speed: 2.8ms preprocess, 10.7ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1 truck, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 bus, 1 truck, 11.9ms
# Speed: 2.2ms preprocess, 11.9ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 cars, 1 bus, 1 truck, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 1 truck, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 1 truck, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 truck, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 5.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 truck, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 16.4ms
# Speed: 2.9ms preprocess, 16.4ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 truck, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 5.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 1 truck, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 11.4ms
# Speed: 2.3ms preprocess, 11.4ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 6.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 4.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 18.2ms
# Speed: 2.5ms preprocess, 18.2ms inference, 6.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 truck, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 11.6ms
# Speed: 2.4ms preprocess, 11.6ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 19.0ms
# Speed: 1.9ms preprocess, 19.0ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 11.2ms
# Speed: 2.5ms preprocess, 11.2ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 20.7ms
# Speed: 2.3ms preprocess, 20.7ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 4.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.6ms
# Speed: 2.5ms preprocess, 11.6ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 15.3ms
# Speed: 2.3ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 6.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 19.9ms
# Speed: 2.8ms preprocess, 19.9ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 5.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 16.7ms
# Speed: 2.7ms preprocess, 16.7ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 19.4ms
# Speed: 3.1ms preprocess, 19.4ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 17.7ms
# Speed: 2.9ms preprocess, 17.7ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 17.7ms
# Speed: 1.9ms preprocess, 17.7ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 17.4ms
# Speed: 1.9ms preprocess, 17.4ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 cars, 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 17.8ms
# Speed: 3.1ms preprocess, 17.8ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 1 truck, 19.6ms
# Speed: 2.4ms preprocess, 19.6ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 cars, 19.4ms
# Speed: 2.4ms preprocess, 19.4ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.8ms
# Speed: 2.6ms preprocess, 12.8ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 cars, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.8ms
# Speed: 2.8ms preprocess, 10.8ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 6.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 cars, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 6.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 8.7ms
# Speed: 3.4ms preprocess, 8.7ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 6.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 5.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 7.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 4.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 5.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 8.8ms
# Speed: 3.0ms preprocess, 8.8ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 5.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 11.9ms
# Speed: 2.3ms preprocess, 11.9ms inference, 6.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.7ms
# Speed: 2.9ms preprocess, 15.7ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 12.4ms
# Speed: 2.9ms preprocess, 12.4ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 5.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.7ms
# Speed: 2.3ms preprocess, 11.7ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 13.2ms
# Speed: 2.3ms preprocess, 13.2ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 6.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 8.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 11.8ms
# Speed: 3.4ms preprocess, 11.8ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 12.6ms
# Speed: 2.3ms preprocess, 12.6ms inference, 4.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 8.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 cars, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 5.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 17.2ms
# Speed: 2.6ms preprocess, 17.2ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 5.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.3ms
# Speed: 2.1ms preprocess, 13.3ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 13.4ms
# Speed: 2.6ms preprocess, 13.4ms inference, 6.2ms postprocess per image at shape (1, 3, 352, 640)
